# %%
import pandas as pd

# %%
moviesDF = pd.read_csv("movies.csv")
ratingsDF = pd.read_csv("ratings.csv")
tagsDF = pd.read_csv("tags.csv")

# %%
moviesDF
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 87580   292731           The Monroy Affaire (2022)
# 87581   292737          Shelter in Solitude (2023)
# 87582   292753                         Orca (2023)
# 87583   292755              The Angry Breed (1968)
# 87584   292757           Race to the Summit (2023)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 87580                                        Drama
# 87581                                 Comedy|Drama
# 87582                                        Drama
# 87583                                        Drama
# 87584                 Action|Adventure|Documentary
#
# [87585 rows x 3 columns]

# %%
ratingsDF
# Out:
#           userId  movieId  rating   timestamp
# 0              1       17     4.0   944249077
# 1              1       25     1.0   944250228
# 2              1       29     2.0   943230976
# 3              1       30     5.0   944249077
# 4              1       32     5.0   943228858
# ...          ...      ...     ...         ...
# 32000199  200948    79702     4.5  1294412589
# 32000200  200948    79796     1.0  1287216292
# 32000201  200948    80350     0.5  1294412671
# 32000202  200948    80463     3.5  1350423800
# 32000203  200948    87304     4.5  1350423523
#
# [32000204 rows x 4 columns]

# %%
movieRatingsDF = ratingsDF.merge(moviesDF, on="movieId", how="inner")

# %%
movieRatingsDF = movieRatingsDF[["title", "genres", "rating"]]
movieRatingsDF
# Out:
#                                                       title  \
# 0                              Sense and Sensibility (1995)
# 1                                  Leaving Las Vegas (1995)
# 2         City of Lost Children, The (Cité des enfants p...
# 3         Shanghai Triad (Yao a yao yao dao waipo qiao) ...
# 4                 Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# ...                                                     ...
# 32000199                 Scott Pilgrim vs. the World (2010)
# 32000200                                   Centurion (2010)
# 32000201                               Vampires Suck (2010)
# 32000202                         Social Network, The (2010)
# 32000203                                   Beginners (2010)
#
#                                           genres  rating
# 0                                  Drama|Romance     4.0
# 1                                  Drama|Romance     1.0
# 2         Adventure|Drama|Fantasy|Mystery|Sci-Fi     2.0
# 3                                    Crime|Drama     5.0
# 4                        Mystery|Sci-Fi|Thriller     5.0
# ...                                          ...     ...
# 32000199   Action|Comedy|Fantasy|Musical|Romance     4.5
# 32000200     Action|Adventure|Drama|Thriller|War     1.0
# 32000201                                  Comedy     0.5
# 32000202                                   Drama     3.5
# 32000203                                   Drama     4.5
#
# [32000204 rows x 3 columns]

# %%
titleHightoLow = movieRatingsDF.sort_values(by=["title", "rating"], ascending=[True, False])
titleHightoLow
